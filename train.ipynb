# %% [markdown]
# # 텐서플로우 음성인식 챌린지

# %%
import tensorflow as tf

# %% [markdown]
# # Data Augmentation

# %%
import numpy as np
import random
import itertools
import librosa
import IPython.display as ipd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
def load_audio_file(file_path):
    input_length = 16000
    data = librosa.core.load(file_path)[0] #, sr=16000
    if len(data)>input_length:
        data = data[:input_length]
    else:
        data = np.pad(data, (0, max(0, input_length - len(data))), "constant")
    return data
def plot_time_series(data):
    fig = plt.figure(figsize=(14, 8))
    plt.title('Raw wave ')
    plt.ylabel('Amplitude')
    plt.plot(np.linspace(0, 1, len(data)), data)
    plt.show()

# %%
print(type(data))
print(data.shape)
# Out:
# <class 'numpy.ndarray'>
# (16000,)

# %%
data = load_audio_file("./train/audio/off/1df483c0_nohash_0.wav")
plot_time_series(data)

# %%
ipd.Audio(data, rate=16000)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Adding white noise 
wn = np.random.randn(len(data))
data_wn = data + 0.005*wn
plot_time_series(data_wn)
# We limited the amplitude of the noise so we can still hear the word even with the noise, 
#which is the objective
ipd.Audio(data_wn, rate=16000)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
len(data)
# Out:
# 16000

# %%
np.random.randn(len(data))
# Out:
# array([ 2.57571288, -0.07094631, -0.29450086, ...,  0.2802788 ,
#        -0.36913947, -1.0947079 ])

# %%
# Shifting the sound
#뒤에 20% 앞으로 붙힘
data_roll = np.roll(data, 3200)
plot_time_series(data_roll)

data_roll2 = np.roll(data, 16000)
plot_time_series(data_roll2)

#ipd.Audio(data_roll2, rate=16000)
ipd.Audio(data_roll, rate=16000)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
len(data_roll)
# Out:
# 16000

# %%
# stretching the sound
def stretch(data, rate=1):
    input_length = 16000
    data = librosa.effects.time_stretch(data, rate)
    if len(data)>input_length:
        data = data[:input_length]
    else:
        data = np.pad(data, (0, max(0, input_length - len(data))), "constant")

    return data

# %%
data_stretch =stretch(data, 0.7)
print("This makes the sound deeper but we can still hear 'off' ")
plot_time_series(data_stretch)
ipd.Audio(data_stretch, rate=16000)
# Out:
# This makes the sound deeper but we can still hear 'off'
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
data_stretch =stretch(data, 0.8)
print("This makes the sound deeper but we can still hear 'off' ")
plot_time_series(data_stretch)
ipd.Audio(data_stretch, rate=16000)
# Out:
# This makes the sound deeper but we can still hear 'off'
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
data_stretch =stretch(data, 1.2)
print("Higher frequencies  ")
plot_time_series(data_stretch)
ipd.Audio(data_stretch, rate=16000)
# Out:
# Higher frequencies
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
data_stretch =stretch(data, 1.4)
print("Higher frequencies  ")
plot_time_series(data_stretch)
ipd.Audio(data_stretch, rate=16000)
# Out:
# Higher frequencies
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
data1 = load_audio_file("./train/audio/bed/079dfce3_nohash_0.wav")
data2 = load_audio_file("./train/audio/bed/079dfce3_nohash_1.wav")
data3 = load_audio_file("./train/audio/bed/079dfce3_nohash_2.wav")

plot_time_series(data1)
plot_time_series(data2)
plot_time_series(data3)

# %%
ipd.Audio(data1, rate=16000)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio(data2, rate=16000)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio(data3, rate=16000)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
